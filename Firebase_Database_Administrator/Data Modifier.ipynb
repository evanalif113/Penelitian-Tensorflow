# %%
# !pip install firebase-admin
import firebase_admin
from firebase_admin import credentials, db
from datetime import datetime  # Untuk konversi timestamp ke human-readable
import pandas as pd
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Konfigurasi database sumber
source_cred = credentials.Certificate("/work/staklimjerukagung-firebase-admin.json")
source_app = firebase_admin.initialize_app(source_cred, {
  'databaseURL': 'https://staklimjerukagung-default-rtdb.asia-southeast1.firebasedatabase.app/'
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Konfigurasi database sumber
#       2 source_cred = credentials.Certificate("/work/staklimjerukagung-firebase-admin.json")
# ----> 3 source_app = firebase_admin.initialize_app(source_cred, {
#       4   'databaseURL': 'https://staklimjerukagung-default-rtdb.asia-southeast1.firebasedatabase.app/'
#       5 })
#
# File ~/venv/lib/python3.11/site-packages/firebase_admin/__init__.py:74, in initialize_app(credential, options, name)
#      71         return app
#      73 if name == _DEFAULT_APP_NAME:
# ---> 74     raise ValueError((
#      75         'The default Firebase app already exists. This means you called '
#      76         'initialize_app() more than once without providing an app name as '
#      77         'the second argument. In most cases you only need to call '
# ...

# %% [markdown]
# > gunakan indexOn rain rate, cari data yang nilainya = 3.7842

# %%
# Menggunakan Firebase Admin SDK untuk mengakses database
ref = db.reference('rain_rate')

# Menggunakan indexOn untuk mencari data dengan nilai rain rate = 3.7842
query = ref.order_by_value().equal_to(3.7842)
results = query.get()

results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Menggunakan Firebase Admin SDK untuk mengakses database
# ----> 2 ref = db.reference('rain_rate')
#       4 # Menggunakan indexOn untuk mencari data dengan nilai rain rate = 3.7842
#       5 query = ref.order_by_value().equal_to(3.7842)
#
# NameError: name 'db' is not defined

# %%
# Initialize the Firebase Admin SDK again to ensure 'db' is defined
import firebase_admin
from firebase_admin import credentials, db

# Re-initialize the app if not already initialized
if not firebase_admin._apps:
    source_cred = credentials.Certificate("/work/staklimjerukagung-firebase-admin.json")
    firebase_admin.initialize_app(source_cred, {
      'databaseURL': 'https://staklimjerukagung-default-rtdb.asia-southeast1.firebasedatabase.app/'
    })

# Access the database reference
ref = db.reference('rain_rate')

# Use indexOn to find data with rain rate = 3.7842
query = ref.order_by_value().equal_to(3.7842)
results = query.get()

results
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/venv/lib/python3.11/site-packages/firebase_admin/db.py:928, in _Client.request(self, method, url, **kwargs)
#     927 try:
# --> 928     return super().request(method, url, **kwargs)
#     929 except requests.exceptions.RequestException as error:
#
# File ~/venv/lib/python3.11/site-packages/firebase_admin/_http_client.py:136, in HttpClient.request(self, method, url, **kwargs)
#     135 resp = self._session.request(method, self.base_url + url, **kwargs)
# --> 136 resp.raise_for_status()
#     137 return resp
#
# File ~/venv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %% [markdown]
# It seems that the Firebase Realtime Database rules do not have an index defined for the path `/rain_rate`. To perform this query efficiently, you need to update the Firebase Realtime Database rules to include an index on the `rain_rate` path. This requires access to the Firebase console to modify the database rules.
#
# If you have access to the Firebase console, you can add the following to your database rules under the `rules` section:
#
# ```json
# "rain_rate": {
#   ".indexOn": ".value"
# }
# ```
#
# After updating the rules, you can retry the query. If you need further assistance with this, please let me know.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=200afad5-8991-4e20-8a55-8751c7aff3b5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

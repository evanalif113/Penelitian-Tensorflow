# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting missingno (from -r ./requirements.txt (line 1))
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting meteostat (from -r ./requirements.txt (line 2))
#   Downloading meteostat-1.7.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: plotly in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 3)) (6.5.0)
# Requirement already satisfied: tensorflow in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 4)) (2.15.1)
# Collecting firebase_admin (from -r ./requirements.txt (line 5))
#   Downloading firebase_admin-7.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting pygwalker (from -r ./requirements.txt (line 6))
#   Downloading pygwalker-0.4.9.15-py3-none-any.whl.metadata (20 kB)
# Collecting openpyxl==3.1.5 (from -r ./requirements.txt (line 7))
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting filterpy==1.4.5 (from -r ./requirements.txt (line 8))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 17.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting openmeteo-requests (from -r ./requirements.txt (line 9))
#   Downloading openmeteo_requests-1.7.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 10)) (2.32.5)
# Collecting requests_cache (from -r ./requirements.txt (line 11))
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting retry_requests (from -r ./requirements.txt (line 12))
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: lxml in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 13)) (6.0.2)
# Requirement already satisfied: pandas in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 14)) (2.1.4)
# Collecting et-xmlfile (from openpyxl==3.1.5->-r ./requirements.txt (line 7))
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy in /root/venv/lib/python3.11/site-packages (from filterpy==1.4.5->-r ./requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: scipy in /root/venv/lib/python3.11/site-packages (from filterpy==1.4.5->-r ./requirements.txt (line 8)) (1.11.4)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.11/site-packages (from filterpy==1.4.5->-r ./requirements.txt (line 8)) (3.8.4)
# Requirement already satisfied: seaborn in /root/venv/lib/python3.11/site-packages (from missingno->-r ./requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: pytz in /root/venv/lib/python3.11/site-packages (from meteostat->-r ./requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /root/venv/lib/python3.11/site-packages (from plotly->-r ./requirements.txt (line 3)) (2.12.0)
# Requirement already satisfied: packaging in /root/venv/lib/python3.11/site-packages (from plotly->-r ./requirements.txt (line 3)) (25.0)
# Requirement already satisfied: absl-py>=1.0.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (65.5.1)
# Requirement already satisfied: six>=1.12.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.76.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /root/venv/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.15.0)
# Collecting cachecontrol>=0.14.3 (from firebase_admin->-r ./requirements.txt (line 5))
#   Downloading cachecontrol-0.14.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-core<3.0.0dev,>=2.25.1 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-firestore>=2.21.0 (from firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_cloud_firestore-2.21.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting google-cloud-storage>=3.1.1 (from firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_cloud_storage-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyjwt>=2.10.1 in /root/venv/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5)) (2.10.1)
# Collecting httpx==0.28.1 (from httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /root/venv/lib/python3.11/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5)) (2025.11.12)
# Collecting httpcore==1.* (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /root/venv/lib/python3.11/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5)) (3.11)
# Collecting h2<5,>=3 (from httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting anywidget (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# Collecting appdirs (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting arrow (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting astor (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cachetools in /root/venv/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (5.5.2)
# Requirement already satisfied: duckdb<2.0.0,>=0.10.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (1.4.1)
# Collecting gw-dsl-parser==0.1.49.1 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading gw_dsl_parser-0.1.49.1-py3-none-any.whl.metadata (1.2 kB)
# Collecting ipylab<=1.0.0 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading ipylab-1.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: ipython in /root/venv/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (9.7.0)
# Collecting ipywidgets (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2 in /root/venv/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (3.1.6)
# Collecting kanaries-track==0.0.5 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading kanaries_track-0.0.5-py3-none-any.whl.metadata (913 bytes)
# Requirement already satisfied: psutil in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: pyarrow in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (17.0.0)
# Requirement already satisfied: pydantic in /root/venv/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (2.11.10)
# Collecting quickjs (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading quickjs-1.19.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (590 bytes)
# Collecting segment-analytics-python==2.2.3 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sqlalchemy in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (1.4.54)
# Collecting sqlglot>=23.15.8 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading sqlglot-28.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: traitlets in /root/venv/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (5.14.3)
# Collecting wasmtime>=12.0.0 (from gw-dsl-parser==0.1.49.1->pygwalker->-r ./requirements.txt (line 6))
#   Downloading wasmtime-39.0.0-py3-none-manylinux1_x86_64.whl.metadata (5.5 kB)
# Collecting backoff>=2.2.1 (from kanaries-track==0.0.5->pygwalker->-r ./requirements.txt (line 6))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting dateutils>=0.6.12 (from kanaries-track==0.0.5->pygwalker->-r ./requirements.txt (line 6))
#   Downloading dateutils-0.6.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting monotonic~=1.5 (from segment-analytics-python==2.2.3->pygwalker->-r ./requirements.txt (line 6))
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dateutil~=2.2 in /root/venv/lib/python3.11/site-packages (from segment-analytics-python==2.2.3->pygwalker->-r ./requirements.txt (line 6)) (2.9.0.post0)
# Collecting niquests>=3.15.2 (from openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading niquests-3.15.2-py3-none-any.whl.metadata (16 kB)
# Collecting openmeteo-sdk>=1.22.0 (from openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading openmeteo_sdk-1.23.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.11/site-packages (from requests->-r ./requirements.txt (line 10)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.11/site-packages (from requests->-r ./requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: attrs>=21.2 in /root/venv/lib/python3.11/site-packages (from requests_cache->-r ./requirements.txt (line 11)) (25.4.0)
# Collecting cattrs>=22.2 (from requests_cache->-r ./requirements.txt (line 11))
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /root/venv/lib/python3.11/site-packages (from requests_cache->-r ./requirements.txt (line 11)) (4.5.0)
# Collecting url-normalize>=1.4 (from requests_cache->-r ./requirements.txt (line 11))
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 14)) (2025.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow->-r ./requirements.txt (line 4)) (0.45.1)
# Collecting msgpack<2.0.0,>=0.5.2 (from cachecontrol>=0.14.3->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading msgpack-1.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (1.65.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /root/venv/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (2.41.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (1.62.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-cloud-firestore>=2.21.0->firebase_admin->-r ./requirements.txt (line 5)) (2.4.1)
# Collecting google-cloud-core<3.0.0,>=1.4.1 (from google-cloud-firestore>=2.21.0->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-cloud-storage>=3.1.1->firebase_admin->-r ./requirements.txt (line 5)) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-cloud-storage>=3.1.1->firebase_admin->-r ./requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: comm>=0.1.3 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipywidgets->pygwalker->-r ./requirements.txt (line 6)) (0.2.2)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->pygwalker->-r ./requirements.txt (line 6))
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->pygwalker->-r ./requirements.txt (line 6))
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator>=4.3.2 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /root/venv/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.6.3)
# Collecting urllib3-future<3,>=2.13.903 (from niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading urllib3_future-2.14.908-py3-none-any.whl.metadata (16 kB)
# Collecting wassima<3,>=1.0.1 (from niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading wassima-2.0.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: cryptography>=3.4.0 in /root/venv/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5)) (44.0.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /root/venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (1.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /root/venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /root/venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /root/venv/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (3.1.3)
# Collecting psygnal>=0.8.1 (from anywidget->pygwalker->-r ./requirements.txt (line 6))
#   Downloading psygnal-0.15.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.11/site-packages (from jinja2->pygwalker->-r ./requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8)) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8)) (3.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /root/venv/lib/python3.11/site-packages (from pydantic->pygwalker->-r ./requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /root/venv/lib/python3.11/site-packages (from pydantic->pygwalker->-r ./requirements.txt (line 6)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /root/venv/lib/python3.11/site-packages (from pydantic->pygwalker->-r ./requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: greenlet!=0.4.17 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from sqlalchemy->pygwalker->-r ./requirements.txt (line 6)) (3.2.4)
# Requirement already satisfied: cffi>=1.12 in /root/venv/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /root/venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /root/venv/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (2.0.0)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /root/venv/lib/python3.11/site-packages (from jedi>=0.18.1->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.11/site-packages (from pexpect>4.3->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /root/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython->pygwalker->-r ./requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /root/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython->pygwalker->-r ./requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: pure-eval in /root/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.2.3)
# Collecting jh2<6.0.0,>=5.0.3 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting qh3<2.0.0,>=1.5.4 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting importlib_resources>=5.10 (from wasmtime>=12.0.0->gw-dsl-parser==0.1.49.1->pygwalker->-r ./requirements.txt (line 6))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pycparser in /root/venv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5)) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /root/venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /root/venv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (3.3.1)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 24.3 MB/s eta 0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading meteostat-1.7.6-py3-none-any.whl (33 kB)
# Downloading firebase_admin-7.1.0-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.1/137.1 kB 17.5 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 10.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.0 MB/s eta 0:00:00
# Downloading pygwalker-0.4.9.15-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 62.7 MB/s eta 0:00:00
# Downloading gw_dsl_parser-0.1.49.1-py3-none-any.whl (956 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.2/956.2 kB 64.1 MB/s eta 0:00:00
# Downloading kanaries_track-0.0.5-py3-none-any.whl (8.6 kB)
# Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl (24 kB)
# Downloading openmeteo_requests-1.7.4-py3-none-any.whl (7.0 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 9.5 MB/s eta 0:00:00
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cachecontrol-0.14.4-py3-none-any.whl (22 kB)
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.5 MB/s eta 0:00:00
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.7/173.7 kB 13.4 MB/s eta 0:00:00
# Downloading google_cloud_firestore-2.21.0-py3-none-any.whl (368 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 368.8/368.8 kB 30.0 MB/s eta 0:00:00
# Downloading google_cloud_storage-3.6.0-py3-none-any.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.0/299.0 kB 34.0 MB/s eta 0:00:00
# Downloading ipylab-1.0.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 11.3 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 15.0 MB/s eta 0:00:00
# Downloading niquests-3.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 kB 15.0 MB/s eta 0:00:00
# Downloading openmeteo_sdk-1.23.0-py3-none-any.whl (18 kB)
# Downloading sqlglot-28.1.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 46.0 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Downloading anywidget-0.9.21-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 17.0 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 7.2 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading quickjs-1.19.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 34.3 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 6.9 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 52.2 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading msgpack-1.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 39.9 MB/s eta 0:00:00
# Downloading psygnal-0.15.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (854 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.3/854.3 kB 56.8 MB/s eta 0:00:00
# Downloading urllib3_future-2.14.908-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.2/683.2 kB 54.5 MB/s eta 0:00:00
# Downloading wasmtime-39.0.0-py3-none-manylinux1_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.1 MB/s eta 0:00:00
# Downloading wassima-2.0.2-py3-none-any.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.8/145.8 kB 25.8 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 111.1 MB/s eta 0:00:00
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 13.2 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.1/394.1 kB 52.7 MB/s eta 0:00:00
# Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 80.2 MB/s eta 0:00:00
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py): started
#   Building wheel for filterpy (setup.py): finished with status 'done'
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=d24af7a6ad026dcad0ac4a7c726a4cd9e468a857785e60ce760c403d63b5797f
#   Stored in directory: /root/.cache/pip/wheels/12/dc/3c/e12983eac132d00f82a20c6cbe7b42ce6e96190ef8fa2d15e1
# Successfully built filterpy
# Installing collected packages: quickjs, monotonic, appdirs, widgetsnbextension, wassima, url-normalize, sqlglot, qh3, psygnal, openmeteo-sdk, msgpack, jupyterlab_widgets, jh2, importlib_resources, hyperframe, hpack, h11, et-xmlfile, cattrs, backoff, astor, anyio, wasmtime, urllib3-future, segment-analytics-python, retry_requests, requests_cache, openpyxl, httpcore, h2, dateutils, cachecontrol, arrow, niquests, meteostat, kanaries-track, ipywidgets, httpx, gw-dsl-parser, google-api-core, filterpy, openmeteo-requests, missingno, ipylab, google-cloud-core, anywidget, pygwalker, google-cloud-storage, google-cloud-firestore, firebase_admin
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.19.2
#     Not uninstalling google-api-core at /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages, outside environment /root/venv
#     Can't uninstall 'google-api-core'. No files were found to uninstall.
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 2.4.1
#     Not uninstalling google-cloud-core at /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages, outside environment /root/venv
#     Can't uninstall 'google-cloud-core'. No files were found to uninstall.
# Successfully installed anyio-4.12.0 anywidget-0.9.21 appdirs-1.4.4 arrow-1.4.0 astor-0.8.1 backoff-2.2.1 cachecontrol-0.14.4 cattrs-25.3.0 dateutils-0.6.12 et-xmlfile-2.0.0 filterpy-1.4.5 firebase_admin-7.1.0 google-api-core-2.28.1 google-cloud-core-2.5.0 google-cloud-firestore-2.21.0 google-cloud-storage-3.6.0 gw-dsl-parser-0.1.49.1 h11-0.16.0 h2-4.3.0 hpack-4.1.0 httpcore-1.0.9 httpx-0.28.1 hyperframe-6.1.0 importlib_resources-6.5.2 ipylab-1.0.0 ipywidgets-8.1.8 jh2-5.0.10 jupyterlab_widgets-3.0.16 kanaries-track-0.0.5 meteostat-1.7.6 missingno-0.5.2 monotonic-1.6 msgpack-1.1.2 niquests-3.15.2 openmeteo-requests-1.7.4 openmeteo-sdk-1.23.0 openpyxl-3.1.5 psygnal-0.15.0 pygwalker-0.4.9.15 qh3-1.5.6 quickjs-1.19.4 requests_cache-1.2.1 retry_requests-2.0.0 segment-analytics-python-2.2.3 sqlglot-28.1.0 url-normalize-2.2.1 urllib3-future-2.14.908 wasmtime-39.0.0 wassima-2.0.2 widgetsnbextension-4.0.15
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=672c3bf7-b636-46e8-b7c0-4f6feec29313' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

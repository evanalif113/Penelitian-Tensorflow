# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting missingno (from -r ./requirements.txt (line 1))
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting meteostat (from -r ./requirements.txt (line 2))
#   Downloading meteostat-1.7.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting plotly (from -r ./requirements.txt (line 3))
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from -r ./requirements.txt (line 4)) (2.19.0)
# Collecting firebase_admin (from -r ./requirements.txt (line 5))
#   Downloading firebase_admin-7.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting pygwalker (from -r ./requirements.txt (line 6))
#   Downloading pygwalker-0.4.9.15-py3-none-any.whl.metadata (20 kB)
# Collecting openpyxl==3.1.5 (from -r ./requirements.txt (line 7))
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting filterpy==1.4.5 (from -r ./requirements.txt (line 8))
#   Downloading filterpy-1.4.5.zip (177 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting openmeteo-requests (from -r ./requirements.txt (line 9))
#   Downloading openmeteo_requests-1.7.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from -r ./requirements.txt (line 10)) (2.32.3)
# Collecting requests_cache (from -r ./requirements.txt (line 11))
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting retry_requests (from -r ./requirements.txt (line 12))
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting lxml (from -r ./requirements.txt (line 13))
#   Downloading lxml-6.0.2-cp311-cp311-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pandas in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from -r ./requirements.txt (line 14)) (2.1.4)
# Collecting et-xmlfile (from openpyxl==3.1.5->-r ./requirements.txt (line 7))
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from filterpy==1.4.5->-r ./requirements.txt (line 8)) (1.26.4)
# Collecting scipy (from filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting matplotlib (from filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading matplotlib-3.10.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting seaborn (from missingno->-r ./requirements.txt (line 1))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pytz in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from meteostat->-r ./requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: narwhals>=1.15.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from plotly->-r ./requirements.txt (line 3)) (1.42.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly->-r ./requirements.txt (line 3)) (24.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (5.29.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (76.0.0)
# Requirement already satisfied: six>=1.12.0 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.9.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.37.1)
# Collecting cachecontrol>=0.14.3 (from firebase_admin->-r ./requirements.txt (line 5))
#   Downloading cachecontrol-0.14.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-core<3.0.0dev,>=2.25.1 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-firestore>=2.21.0 (from firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_cloud_firestore-2.21.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting google-cloud-storage>=3.1.1 (from firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_cloud_storage-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting httpx==0.28.1 (from httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5)) (2025.1.31)
# Collecting httpcore==1.* (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5)) (3.10)
# Collecting h2<5,>=3 (from httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting anywidget (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# Collecting appdirs (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting arrow (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting astor (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cachetools in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: duckdb<2.0.0,>=0.10.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (1.4.1)
# Collecting gw-dsl-parser==0.1.49.1 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading gw_dsl_parser-0.1.49.1-py3-none-any.whl.metadata (1.2 kB)
# Collecting ipylab<=1.0.0 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading ipylab-1.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: ipython in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (8.12.3)
# Collecting ipywidgets (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (3.1.6)
# Collecting kanaries-track==0.0.5 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading kanaries_track-0.0.5-py3-none-any.whl.metadata (913 bytes)
# Requirement already satisfied: psutil in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: pyarrow in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (17.0.0)
# Requirement already satisfied: pydantic in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (2.11.7)
# Collecting quickjs (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading quickjs-1.19.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (590 bytes)
# Collecting segment-analytics-python==2.2.3 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sqlalchemy in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (1.4.54)
# Collecting sqlglot>=23.15.8 (from pygwalker->-r ./requirements.txt (line 6))
#   Downloading sqlglot-28.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: traitlets in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pygwalker->-r ./requirements.txt (line 6)) (5.14.3)
# Collecting wasmtime>=12.0.0 (from gw-dsl-parser==0.1.49.1->pygwalker->-r ./requirements.txt (line 6))
#   Downloading wasmtime-39.0.0-py3-none-manylinux1_x86_64.whl.metadata (5.5 kB)
# Collecting backoff>=2.2.1 (from kanaries-track==0.0.5->pygwalker->-r ./requirements.txt (line 6))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting dateutils>=0.6.12 (from kanaries-track==0.0.5->pygwalker->-r ./requirements.txt (line 6))
#   Downloading dateutils-0.6.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting monotonic~=1.5 (from segment-analytics-python==2.2.3->pygwalker->-r ./requirements.txt (line 6))
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dateutil~=2.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from segment-analytics-python==2.2.3->pygwalker->-r ./requirements.txt (line 6)) (2.9.0.post0)
# Collecting niquests>=3.15.2 (from openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading niquests-3.15.2-py3-none-any.whl.metadata (16 kB)
# Collecting openmeteo-sdk>=1.22.0 (from openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading openmeteo_sdk-1.23.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->-r ./requirements.txt (line 10)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->-r ./requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: attrs>=21.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from requests_cache->-r ./requirements.txt (line 11)) (24.2.0)
# Collecting cattrs>=22.2 (from requests_cache->-r ./requirements.txt (line 11))
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from requests_cache->-r ./requirements.txt (line 11)) (4.2.2)
# Collecting url-normalize>=1.4 (from requests_cache->-r ./requirements.txt (line 11))
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: tzdata>=2022.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pandas->-r ./requirements.txt (line 14)) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->-r ./requirements.txt (line 4)) (0.45.1)
# Collecting msgpack<2.0.0,>=0.5.2 (from cachecontrol>=0.14.3->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading msgpack-1.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting attrs>=21.2 (from requests_cache->-r ./requirements.txt (line 11))
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow->-r ./requirements.txt (line 4))
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (1.65.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (2.34.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (1.62.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-cloud-firestore>=2.21.0->firebase_admin->-r ./requirements.txt (line 5)) (2.4.1)
# Collecting google-cloud-core<3.0.0,>=1.4.1 (from google-cloud-firestore>=2.21.0->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-cloud-storage>=3.1.1->firebase_admin->-r ./requirements.txt (line 5)) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-cloud-storage>=3.1.1->firebase_admin->-r ./requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: comm>=0.1.3 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipywidgets->pygwalker->-r ./requirements.txt (line 6)) (0.2.2)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->pygwalker->-r ./requirements.txt (line 6))
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->pygwalker->-r ./requirements.txt (line 6))
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: backcall in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: decorator in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.2.1)
# Requirement already satisfied: pickleshare in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (2.19.1)
# Requirement already satisfied: stack-data in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from ipython->pygwalker->-r ./requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->-r ./requirements.txt (line 4)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->-r ./requirements.txt (line 4)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->-r ./requirements.txt (line 4)) (0.14.1)
# Collecting urllib3-future<3,>=2.13.903 (from niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading urllib3_future-2.14.908-py3-none-any.whl.metadata (16 kB)
# Collecting wassima<3,>=1.0.1 (from niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading wassima-2.0.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow->-r ./requirements.txt (line 4))
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: cryptography>=3.4.0 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5)) (44.0.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow->-r ./requirements.txt (line 4)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow->-r ./requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow->-r ./requirements.txt (line 4)) (3.1.3)
# Collecting psygnal>=0.8.1 (from anywidget->pygwalker->-r ./requirements.txt (line 6))
#   Downloading psygnal-0.15.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->pygwalker->-r ./requirements.txt (line 6)) (3.0.2)
# Collecting contourpy>=1.0.1 (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading fonttools-4.61.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (113 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib->filterpy==1.4.5->-r ./requirements.txt (line 8))
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pydantic->pygwalker->-r ./requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pydantic->pygwalker->-r ./requirements.txt (line 6)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pydantic->pygwalker->-r ./requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from sqlalchemy->pygwalker->-r ./requirements.txt (line 6)) (3.2.4)
# Requirement already satisfied: cffi>=1.12 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (4.9)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase_admin->-r ./requirements.txt (line 5))
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from jedi>=0.16->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pexpect>4.3->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.2.13)
# Collecting jh2<6.0.0,>=5.0.3 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting qh3<2.0.0,>=1.5.4 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests->-r ./requirements.txt (line 9))
#   Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting importlib_resources>=5.10 (from wasmtime>=12.0.0->gw-dsl-parser==0.1.49.1->pygwalker->-r ./requirements.txt (line 6))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->-r ./requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from stack-data->ipython->pygwalker->-r ./requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from stack-data->ipython->pygwalker->-r ./requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: pure-eval in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from stack-data->ipython->pygwalker->-r ./requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: pycparser in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase_admin->-r ./requirements.txt (line 5)) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->-r ./requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase_admin->-r ./requirements.txt (line 5)) (0.6.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading meteostat-1.7.6-py3-none-any.whl (33 kB)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 154.5 MB/s eta 0:00:00
# Downloading firebase_admin-7.1.0-py3-none-any.whl (137 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading pygwalker-0.4.9.15-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 57.2 MB/s eta 0:00:00
# Downloading gw_dsl_parser-0.1.49.1-py3-none-any.whl (956 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.2/956.2 kB 80.2 MB/s eta 0:00:00
# Downloading kanaries_track-0.0.5-py3-none-any.whl (8.6 kB)
# Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl (24 kB)
# Downloading openmeteo_requests-1.7.4-py3-none-any.whl (7.0 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading lxml-6.0.2-cp311-cp311-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 154.3 MB/s eta 0:00:00
# Downloading cachecontrol-0.14.4-py3-none-any.whl (22 kB)
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Downloading google_cloud_firestore-2.21.0-py3-none-any.whl (368 kB)
# Downloading google_cloud_storage-3.6.0-py3-none-any.whl (299 kB)
# Downloading ipylab-1.0.0-py3-none-any.whl (100 kB)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading niquests-3.15.2-py3-none-any.whl (167 kB)
# Downloading openmeteo_sdk-1.23.0-py3-none-any.whl (18 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading sqlglot-28.1.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 27.0 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Downloading anywidget-0.9.21-py3-none-any.whl (231 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading matplotlib-3.10.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 128.1 MB/s eta 0:00:00
# Downloading quickjs-1.19.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 108.0 MB/s eta 0:00:00
# Downloading scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 85.1 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (355 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Downloading fonttools-4.61.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 94.8 MB/s eta 0:00:00
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 62.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 97.4 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading msgpack-1.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (426 kB)
# Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 157.6 MB/s eta 0:00:00
# Downloading psygnal-0.15.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (854 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.3/854.3 kB 52.8 MB/s eta 0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading urllib3_future-2.14.908-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.2/683.2 kB 42.0 MB/s eta 0:00:00
# Downloading wasmtime-39.0.0-py3-none-manylinux1_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 86.5 MB/s eta 0:00:00
# Downloading wassima-2.0.2-py3-none-any.whl (145 kB)
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 89.6 MB/s eta 0:00:00
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (394 kB)
# Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 84.8 MB/s eta 0:00:00
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py): started
#   Building wheel for filterpy (setup.py): finished with status 'done'
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110514 sha256=a4948019e0368bc43ed0a0cd802a01d59b04fc3c3084a6254835f05f35051be7
#   Stored in directory: /root/.cache/pip/wheels/12/dc/3c/e12983eac132d00f82a20c6cbe7b42ce6e96190ef8fa2d15e1
# Successfully built filterpy
# Installing collected packages: quickjs, monotonic, flatbuffers, appdirs, widgetsnbextension, wassima, url-normalize, typing-extensions, sqlglot, scipy, qh3, pyparsing, pyjwt, psygnal, plotly, pillow, openmeteo-sdk, msgpack, lxml, kiwisolver, jupyterlab_widgets, jh2, importlib_resources, hyperframe, hpack, h11, fonttools, et-xmlfile, cycler, contourpy, backoff, attrs, astor, wasmtime, urllib3-future, segment-analytics-python, retry_requests, openpyxl, matplotlib, httpcore, h2, dateutils, cattrs, cachecontrol, arrow, anyio, seaborn, requests_cache, niquests, meteostat, kanaries-track, httpx, gw-dsl-parser, google-api-core, filterpy, openmeteo-requests, missingno, ipywidgets, google-cloud-core, ipylab, google-cloud-storage, google-cloud-firestore, anywidget, pygwalker, firebase_admin
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 25.2.10
#     Not uninstalling flatbuffers at /usr/local/lib/python3.11/dist-packages, outside environment /root/venv
#     Can't uninstall 'flatbuffers'. No files were found to uninstall.
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Not uninstalling typing-extensions at /usr/local/lib/python3.11/dist-packages, outside environment /root/venv
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.7
#     Not uninstalling pyparsing at /usr/lib/python3/dist-packages, outside environment /root/venv
#     Can't uninstall 'pyparsing'. No files were found to uninstall.
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.9.0
#     Not uninstalling pyjwt at /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages, outside environment /root/venv
#     Can't uninstall 'PyJWT'. No files were found to uninstall.
#   Attempting uninstall: attrs
#     Found existing installation: attrs 24.2.0
#     Not uninstalling attrs at /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages, outside environment /root/venv
#     Can't uninstall 'attrs'. No files were found to uninstall.
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.19.2
#     Not uninstalling google-api-core at /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages, outside environment /root/venv
#     Can't uninstall 'google-api-core'. No files were found to uninstall.
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 2.4.1
#     Not uninstalling google-cloud-core at /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages, outside environment /root/venv
#     Can't uninstall 'google-cloud-core'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery-storage 2.16.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.3 which is incompatible.
# deepnote-toolkit 1.1.6 requires requests<3,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# deepnote-toolkit 1.1.6 requires urllib3<3,>=2.5.0; python_version >= "3.10", but you have urllib3 2.3.0 which is incompatible.
# Successfully installed anyio-4.12.0 anywidget-0.9.21 appdirs-1.4.4 arrow-1.4.0 astor-0.8.1 attrs-25.4.0 backoff-2.2.1 cachecontrol-0.14.4 cattrs-25.3.0 contourpy-1.3.3 cycler-0.12.1 dateutils-0.6.12 et-xmlfile-2.0.0 filterpy-1.4.5 firebase_admin-7.1.0 flatbuffers-25.9.23 fonttools-4.61.0 google-api-core-2.28.1 google-cloud-core-2.5.0 google-cloud-firestore-2.21.0 google-cloud-storage-3.6.0 gw-dsl-parser-0.1.49.1 h11-0.16.0 h2-4.3.0 hpack-4.1.0 httpcore-1.0.9 httpx-0.28.1 hyperframe-6.1.0 importlib_resources-6.5.2 ipylab-1.0.0 ipywidgets-8.1.8 jh2-5.0.10 jupyterlab_widgets-3.0.16 kanaries-track-0.0.5 kiwisolver-1.4.9 lxml-6.0.2 matplotlib-3.10.7 meteostat-1.7.6 missingno-0.5.2 monotonic-1.6 msgpack-1.1.2 niquests-3.15.2 openmeteo-requests-1.7.4 openmeteo-sdk-1.23.0 openpyxl-3.1.5 pillow-12.0.0 plotly-6.5.0 psygnal-0.15.0 pygwalker-0.4.9.15 pyjwt-2.10.1 pyparsing-3.2.5 qh3-1.5.6 quickjs-1.19.4 requests_cache-1.2.1 retry_requests-2.0.0 scipy-1.16.3 seaborn-0.13.2 segment-analytics-python-2.2.3 sqlglot-28.1.0 typing-extensions-4.15.0 url-normalize-2.2.1 urllib3-future-2.14.908 wasmtime-39.0.0 wassima-2.0.2 widgetsnbextension-4.0.15
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=672c3bf7-b636-46e8-b7c0-4f6feec29313' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
